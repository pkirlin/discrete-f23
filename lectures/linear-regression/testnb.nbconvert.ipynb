# %% [markdown]
# # Welcome to Machine Learning!
#
# This is a Jupyter notebook.

# %%
# Here is some Python code.
# Press shift-enter to run it.

print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Here is a cell.

# %% [markdown]
# Here is a noncomment cell.

# %%
print
# Out:
# <function print>

# %% [markdown]
# ![image.png](attachment:28959a16-dcb6-49f2-90c2-ba87a938cbc6.png)
